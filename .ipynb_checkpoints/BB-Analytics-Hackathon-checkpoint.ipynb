# %% [markdown]
# # Reds Baseball Analytics 2024 Hackathon
#
# by Adi Krish, Prasheeth Venkat, Vrishank Gosh

# %% [markdown]
# ## Introduction
#
# TODO: Basic Intro

# %% [markdown]
# **Notice: I have made several assumptions regarding my understanding and approach to this assessment:**
#
# - TODO: List assumptions

# %% [markdown]
# ## Data Ingestion

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class ProcessPitcherData:
    def load_pitcher_data(self, pitcher_data_file):
        # load pitcher data
        pitcher_data = pd.read_csv(pitcher_data_file)
        return pitcher_data

# %%
# file path for pitcher data
pitcher_data_file = 'fangraphs_season_level.csv'

# create instance of ProcessPitcherData class
process_pitcher_data = ProcessPitcherData()

# load pitcher data
pitcher_data = process_pitcher_data.load_pitcher_data(pitcher_data_file)

pitcher_data.head()
# Out:
#    PlayerId  MLBAMID            Name      NameASCII Throws  Season  Age  \
# 0        18   491703  NeftalÃ­ Feliz  Neftali Feliz      R    2021   33
# 1      1157   488984    Tommy Hunter   Tommy Hunter      R    2021   34
# 2      1159   461865   Andrew Romine  Andrew Romine      R    2021   35
# 3      1246   456713       Matt Bush      Matt Bush      R    2021   35
# 4      1247   493603   Adam Ottavino  Adam Ottavino      R    2021   35
#
#     Team Role   G  ...  Pit_plus_FC  Stf_plus_FS  Loc_plus_FS  Pit_plus_FS  \
# 0  - - -   RP   5  ...          NaN          NaN          NaN          NaN
# 1    NYM   RP   3  ...   103.100000          NaN          NaN          NaN
# 2    CHC   RP   1  ...          NaN          NaN          NaN          NaN
# 3    TEX   RP   4  ...          NaN          NaN          NaN          NaN
# 4    BOS   RP  69  ...    66.583333          NaN          NaN          NaN
#
#    Stf_plus_FO  Loc_plus_FO  Pit_plus_FO  Stuff_plus  Location_plus  \
# 0          NaN          NaN          NaN  104.316418      95.123881
# 1          NaN          NaN          NaN   86.285556      94.884444
# 2          NaN          NaN          NaN   43.925000     108.425000
# 3          NaN          NaN          NaN  124.852174      98.340580
# 4          NaN          NaN          NaN  116.269527      94.625394
#
#    Pitching_plus
# 0      95.873134
# 1      95.112222
# 2      99.200000
# 3     102.611594
# 4     102.238617
#
# [5 rows x 308 columns]

# %% [markdown]
# ## Data Exploration

# %%
# import 
pitcher_delta_df = pd.read_csv('pitcher_delta_grade.csv')

# Drop name column
pitcher_delta_df = pitcher_delta_df.drop(columns=['player_name'])

pitcher_delta_df.head()
# Out:
#    delta_diff  delta_avg  MLBAMID
# 0    0.012000  -0.085667   663897
# 1    0.132329  -0.080487   596112
# 2    0.010583  -0.073286   641525
# 3    0.054542  -0.072396   600986
# 4    0.111389  -0.064529   570731

# %%
# merge dataframes
pitcher_data = pd.merge(pitcher_data, pitcher_delta_df, on='MLBAMID')

pitcher_data.head()
# Out:
#    PlayerId  MLBAMID          Name     NameASCII Throws  Season  Age Team  \
# 0      1157   488984  Tommy Hunter  Tommy Hunter      R    2021   34  NYM
# 1      1157   488984  Tommy Hunter  Tommy Hunter      R    2022   35  NYM
# 2      1157   488984  Tommy Hunter  Tommy Hunter      R    2023   36  NYM
# 3      1157   488984  Tommy Hunter  Tommy Hunter      R    2021   34  NYM
# 4      1246   456713     Matt Bush     Matt Bush      R    2021   35  TEX
#
#   Role   G  ...  Loc_plus_FS  Pit_plus_FS  Stf_plus_FO  Loc_plus_FO  \
# 0   RP   3  ...          NaN          NaN          NaN          NaN
# 1   RP  18  ...          NaN          NaN          NaN          NaN
# 2   RP  14  ...          NaN          NaN          NaN          NaN
# 3   SP   1  ...          NaN          NaN          NaN          NaN
# 4   RP   4  ...          NaN          NaN          NaN          NaN
#
#    Pit_plus_FO  Stuff_plus  Location_plus  Pitching_plus  delta_diff  \
# 0          NaN   86.285556      94.884444      95.112222    0.037060
# 1          NaN   95.934758     108.332194     101.498006    0.037060
# 2          NaN   82.804360     105.339510     100.527793    0.037060
# 3          NaN   96.164706     114.752941     107.764706    0.037060
# 4          NaN  124.852174      98.340580     102.611594    0.000057
#
#    delta_avg
# 0   0.008007
# 1   0.008007
# 2   0.008007
# 3   0.008007
# 4   0.014121
#
# [5 rows x 310 columns]

# %%
print(f"Pitcher data shape: {pitcher_data.shape}")
 
print(f" Number of starting pitchers{pitcher_data[pitcher_data['Role'] == 'SP'].shape}")

print(f" Number of relief pitchers{pitcher_data[pitcher_data['Role'] == 'RP'].shape}")
# Out:
# Pitcher data shape: (2505, 310)
#  Number of starting pitchers(947, 310)
#  Number of relief pitchers(1558, 310)

# %% [raw]
# ## Data Processing

# %%
# Filter data to 2023 season
pitcher_data = pitcher_data[pitcher_data['Season'] == 2023]

# Filter to only include number of innings pitched
pitcher_data = pitcher_data[pitcher_data['IP'] > 50]

print(f"Pitcher data shape: {pitcher_data.shape}")
# Out:
# Pitcher data shape: (331, 310)

# %%
filtered_pitcher_data = pitcher_data[['Name','ERA', 'K_pct', 'WHIP', 'delta_diff', 'delta_avg', 'Season', 'Role', 'IP']].copy()

filtered_pitcher_data.head()
# Out:
#              Name       ERA   K_pct      WHIP  delta_diff  delta_avg  Season  \
# 10  Adam Ottavino  3.210809  0.2375  1.216216    0.069955  -0.044033    2023
# 15   Zack Greinke  5.015267  0.1621  1.267176    0.006770   0.006281    2023
# 36   Ryan Brasier  3.016758  0.2353  1.022346    0.146894   0.054887    2023
# 42  JosÃ© Cisnero  5.308992  0.2622  1.483147    0.008057   0.020210    2023
# 45  Craig Kimbrel  3.260870  0.3381  1.043478    0.093141  -0.052338    2023
#
#    Role     IP
# 10   RP   61.2
# 15   SP  131.0
# 36   RP   59.2
# 42   RP   59.1
# 45   RP   69.0

# %%
# Drop any rows with missing data
filtered_pitcher_data = filtered_pitcher_data.dropna()

print(f"Pitcher data shape: {filtered_pitcher_data.shape}")

filtered_pitcher_data.head()
# Out:
# Pitcher data shape: (331, 9)
#              Name       ERA   K_pct      WHIP  delta_diff  delta_avg  Season  \
# 10  Adam Ottavino  3.210809  0.2375  1.216216    0.069955  -0.044033    2023
# 15   Zack Greinke  5.015267  0.1621  1.267176    0.006770   0.006281    2023
# 36   Ryan Brasier  3.016758  0.2353  1.022346    0.146894   0.054887    2023
# 42  JosÃ© Cisnero  5.308992  0.2622  1.483147    0.008057   0.020210    2023
# 45  Craig Kimbrel  3.260870  0.3381  1.043478    0.093141  -0.052338    2023
#
#    Role     IP
# 10   RP   61.2
# 15   SP  131.0
# 36   RP   59.2
# 42   RP   59.1
# 45   RP   69.0

# %%
# Spit to starting and relief pitchers
sp_pitchers = filtered_pitcher_data[filtered_pitcher_data['Role'] == 'SP'].copy()

rp_pitchers = filtered_pitcher_data[filtered_pitcher_data['Role'] == 'RP'].copy()

print(f" Number of starting pitchers{sp_pitchers.shape}")

print(f" Number of relief pitchers{rp_pitchers.shape}")
# Out:
#  Number of starting pitchers(176, 9)
#  Number of relief pitchers(155, 9)

# %%
# Compare Starting pitchers ERA vs Delta Diff
plt.scatter(sp_pitchers['delta_diff'], sp_pitchers['ERA'] )
plt.title('Starting Pitchers ERA vs Delta Diff')
plt.xlabel('Delta Diff')
plt.ylabel('ERA')
plt.show()

# Compare Starting pitchers WHIP vs Delta Diff
plt.scatter(sp_pitchers['delta_diff'], sp_pitchers['WHIP'])
plt.title('Starting Pitchers WHIP vs Delta Diff')
plt.xlabel('Delta Diff')
plt.ylabel('WHIP')
plt.show()

# Compare Starting pitchers K_pct vs Delta Diff
plt.scatter(sp_pitchers['delta_diff'], sp_pitchers['K_pct'] )
plt.title('Starting Pitchers K_pct vs Delta Diff')
plt.xlabel('Delta Diff')
plt.ylabel('K%')
plt.show()

# Compare Starting pitchers IP vs Delta Diff
plt.scatter(sp_pitchers['delta_diff'], sp_pitchers['IP'] )
plt.title('Starting Pitchers IP vs Delta Diff')
plt.xlabel('Delta Diff')
plt.ylabel('IP')
plt.show()

# %%
# Find right outliers for starting pitchers
# Tony Gonsolin in addition to these other pitchers clearly stands out here as a pitcher
sp_right_outliers = sp_pitchers[sp_pitchers['ERA'] < 5]

sp_right_outliers = sp_right_outliers[sp_right_outliers['delta_diff'] > 0.0325]

sp_right_outliers
# Out:
#                Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 741   Tony Gonsolin  4.980583  0.1885  1.223301    0.069117   0.031552
# 1570    Reese Olson  4.319998  0.2507  1.189090    0.044119   0.017490
# 1828  Andrew Heaney  4.082917  0.2322  1.368289    0.041986   0.021455
# 1893  Nestor Cortes  4.973687  0.2519  1.247369    0.048180   0.014208
# 2433      Bryan Woo  4.209124  0.2507  1.209125    0.035925   0.011314
#
#       Season Role     IP
# 741     2023   SP  103.0
# 1570    2023   SP   91.2
# 1828    2023   SP  136.2
# 1893    2023   SP   63.1
# 2433    2023   SP   87.2

# %% [markdown]
# ## Data Analysis and Model Building

# %%
features = rp_pitchers[['ERA', 'K_pct', 'WHIP', 'delta_diff', 'delta_avg']]

# Standardize the data
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features)

# Create a kmeans model on our data, using k clusters. Random_state helps ensure that the algorithm returns the same results each time.
model = KMeans(n_clusters=4, random_state=42)

# Use the fit method to fit the model to the features from the dataframe
rp_pitchers['cluster'] = model.fit_predict(scaled_features)

# Create a scatter plot of the data, coloring by cluster
plt.scatter(rp_pitchers['ERA'], rp_pitchers['delta_diff'], c=rp_pitchers['cluster'], cmap='viridis')
plt.xlabel('ERA')
plt.ylabel('Delta Differece')

# Display the plot
plt.show()

# %% [markdown]
# ### Cluster Analysis

# %%
# Print value counts for each cluster
print(rp_pitchers['cluster'].value_counts())
# Out:
# 0    62
# 2    42
# 1    37
# 3    14
# Name: cluster, dtype: int64

# %%
rp_pitchers[['Name', 'cluster']].head()
# Out:
#              Name  cluster
# 10  Adam Ottavino        2
# 36   Ryan Brasier        3
# 42  JosÃ© Cisnero        1
# 45  Craig Kimbrel        2
# 63   Luis GarcÃ­a        1

# %%
ohtani_data = sp_pitchers[sp_pitchers['Name'].str.contains('Ohtani')]
ohtani_data
# Out:
#                Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 2390  Shohei Ohtani  3.136364  0.3145  1.060606    0.003818  -0.009127
#
#       Season Role     IP
# 2390    2023   SP  132.0

# %%
gerrit_cole_data = sp_pitchers[sp_pitchers['Name'].str.contains('Gerrit')]

gerrit_cole_data
# Out:
#              Name       ERA   K_pct      WHIP  delta_diff  delta_avg  Season  \
# 2325  Gerrit Cole  2.626794  0.2704  0.980861    0.000144  -0.013463    2023
#
#      Role     IP
# 2325   SP  209.0

# %%
blake_snell_data = sp_pitchers[sp_pitchers['Name'].str.contains('Blake Snell')]
blake_snell_data
# Out:
#              Name   ERA   K_pct      WHIP  delta_diff  delta_avg  Season Role  \
# 2454  Blake Snell  2.25  0.3154  1.188889    0.028536  -0.023045    2023   SP
#
#          IP
# 2454  180.0

# %% [markdown]
# #### Explore Clusters

# %%
# Explore Cluster 0
cluster_0 = rp_pitchers[rp_pitchers['cluster'] == 0]
cluster_0.describe()
# Out:
#              ERA      K_pct       WHIP  delta_diff  delta_avg  Season  \
# count  62.000000  62.000000  62.000000   62.000000  62.000000    62.0
# mean    3.573011   0.254265   1.216238    0.024578  -0.009728  2023.0
# std     0.519666   0.039627   0.089924    0.015681   0.013622     0.0
# min     2.608696   0.163400   1.014925    0.001669  -0.035513  2023.0
# 25%     3.145499   0.224100   1.159565    0.012435  -0.019525  2023.0
# 50%     3.616708   0.254350   1.221889    0.023987  -0.011882  2023.0
# 75%     3.916488   0.284050   1.287687    0.034267   0.001615  2023.0
# max     5.000000   0.335800   1.428001    0.069589   0.013643  2023.0
#
#               IP  cluster
# count  62.000000     62.0
# mean   62.167742      0.0
# std     8.184347      0.0
# min    50.100000      0.0
# 25%    55.200000      0.0
# 50%    62.050000      0.0
# 75%    66.100000      0.0
# max    83.100000      0.0

# %%
cluster_0.sort_values(by='ERA', ascending=True).head()
# Out:
#                  Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 758       Jason Foley  2.608696  0.1993  1.159420    0.010483  -0.007935
# 2219        Alex Wood  2.682121  0.1667  1.271524    0.008405   0.001048
# 533   Raisel Iglesias  2.748501  0.2944  1.185628    0.014288  -0.013955
# 1719     Brooks Raley  2.798784  0.2585  1.262197    0.029380  -0.021466
# 1803    Wandy Peralta  2.833333  0.2247  1.222222    0.026667   0.004225
#
#       Season Role    IP  cluster
# 758     2023   RP  69.0        0
# 2219    2023   RP  50.1        0
# 533     2023   RP  55.2        0
# 1719    2023   RP  54.2        0
# 1803    2023   RP  54.0        0

# %%
cluster_1 = rp_pitchers[rp_pitchers['cluster'] == 1]
cluster_1.describe()
# Out:
#              ERA      K_pct       WHIP  delta_diff  delta_avg  Season  \
# count  37.000000  37.000000  37.000000   37.000000  37.000000    37.0
# mean    4.817572   0.231900   1.470333    0.022171  -0.000308  2023.0
# std     0.811957   0.045071   0.081772    0.016034   0.013152     0.0
# min     3.543752   0.142400   1.360250    0.000152  -0.030337  2023.0
# 25%     4.142043   0.192300   1.405062    0.009254  -0.010265  2023.0
# 50%     4.745455   0.244700   1.455446    0.019164  -0.001103  2023.0
# 75%     5.308992   0.262200   1.529704    0.031335   0.007556  2023.0
# max     6.788575   0.325000   1.696429    0.076113   0.023557  2023.0
#
#               IP  cluster
# count  37.000000     37.0
# mean   59.229730      1.0
# std     7.337872      0.0
# min    50.100000      1.0
# 25%    54.000000      1.0
# 50%    58.100000      1.0
# 75%    63.100000      1.0
# max    84.100000      1.0

# %%
cluster_1.sort_values(by='ERA', ascending=True).head()
# Out:
#                  Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 1973    Cionel PÃ©rez  3.543752  0.1781  1.556251    0.014573   0.006267
# 236         Derek Law  3.681820  0.1920  1.383118    0.019164   0.005132
# 1154        Jose Cuas  3.836844  0.2447  1.484211    0.016068  -0.004233
# 1916       Alex Young  3.857148  0.2119  1.360250    0.019999   0.023557
# 336   Carlos EstÃ©vez  3.898398  0.2776  1.491979    0.000917   0.002460
#
#       Season Role    IP  cluster
# 1973    2023   RP  53.1        1
# 236     2023   RP  51.1        1
# 1154    2023   RP  63.1        1
# 1916    2023   RP  53.2        1
# 336     2023   RP  62.1        1

# %%
# Explore Cluster 2
cluster_2 = rp_pitchers[rp_pitchers['cluster'] == 2]
cluster_2.describe()
# Out:
#              ERA      K_pct       WHIP  delta_diff  delta_avg  Season  \
# count  42.000000  42.000000  42.000000   42.000000  42.000000    42.0
# mean    2.421501   0.291807   1.054824    0.039827  -0.030391  2023.0
# std     0.622789   0.059029   0.107448    0.028116   0.016457     0.0
# min     1.051949   0.180000   0.831522    0.001699  -0.080487  2023.0
# 25%     2.017301   0.246875   0.975418    0.015230  -0.042633  2023.0
# 50%     2.555230   0.286350   1.045324    0.038122  -0.028445  2023.0
# 75%     3.017352   0.327375   1.149604    0.052544  -0.019775  2023.0
# max     3.281770   0.464100   1.251429    0.132329   0.001372  2023.0
#
#               IP  cluster
# count  42.000000     42.0
# mean   61.602381      2.0
# std     7.923706      0.0
# min    51.100000      2.0
# 25%    55.425000      2.0
# 50%    60.600000      2.0
# 75%    66.600000      2.0
# max    84.100000      2.0

# %%
cluster_2.sort_values(by='ERA', ascending=True).head()
# Out:
#                   Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 167       Chris Martin  1.051949  0.2312  1.032468    0.008177  -0.039294
# 900   Brusdar Graterol  1.239797  0.1800  0.979592    0.037828  -0.030753
# 1800        Josh Hader  1.278107  0.3680  1.100592    0.009668  -0.018375
# 1245   FÃ©lix Bautista  1.475410  0.4641  0.918033    0.059172  -0.052545
# 1822         Tim Mayza  1.518751  0.2465  1.218751    0.054143  -0.044487
#
#       Season Role    IP  cluster
# 167     2023   RP  51.1        2
# 900     2023   RP  65.1        2
# 1800    2023   RP  56.1        2
# 1245    2023   RP  61.0        2
# 1822    2023   RP  53.1        2

# %%
# Explore Cluster 3
cluster_3 = rp_pitchers[rp_pitchers['cluster'] == 3]
cluster_3.describe()
# Out:
#              ERA      K_pct       WHIP  delta_diff  delta_avg  Season  \
# count  14.000000  14.000000  14.000000   14.000000  14.000000    14.0
# mean    4.020692   0.258157   1.255210    0.084511   0.038243  2023.0
# std     0.981481   0.046998   0.129646    0.030170   0.015934     0.0
# min     2.926107   0.166000   1.022346    0.054955   0.013182  2023.0
# 25%     3.044557   0.235850   1.147035    0.060024   0.022654  2023.0
# 50%     3.960125   0.257550   1.295117    0.075245   0.042924  2023.0
# 75%     4.828872   0.284625   1.323729    0.107288   0.052118  2023.0
# max     5.568753   0.347400   1.500001    0.146894   0.061797  2023.0
#
#               IP  cluster
# count  14.000000     14.0
# mean   62.542857      3.0
# std     6.894448      0.0
# min    52.100000      3.0
# 25%    58.300000      3.0
# 50%    63.100000      3.0
# 75%    67.800000      3.0
# max    74.000000      3.0

# %%
# Sort by ERA
cluster_3.sort_values(by='ERA', ascending=True).head()
# Out:
#                 Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 976     Camilo Doval  2.926107  0.3096  1.137930    0.123078   0.052589
# 36      Ryan Brasier  3.016758  0.2353  1.022346    0.146894   0.054887
# 2143  Caleb Ferguson  3.018632  0.2754  1.360248    0.121375   0.061797
# 438     Tyler Rogers  3.040541  0.1942  1.148649    0.064327   0.022109
# 1346      Matt Brash  3.056607  0.3474  1.330190    0.067619   0.026916
#
#       Season Role    IP  cluster
# 976     2023   RP  67.2        3
# 36      2023   RP  59.2        3
# 2143    2023   RP  53.2        3
# 438     2023   RP  74.0        3
# 1346    2023   RP  70.2        3

# %%
# Find the cluster of right outliers
sp_right_outliers['cluster'] = model.predict(scaler.transform(sp_right_outliers[['ERA', 'K_pct', 'WHIP', 'delta_diff', 'delta_avg']]))
sp_right_outliers
# Out:
#                Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 741   Tony Gonsolin  4.980583  0.1885  1.223301    0.069117   0.031552
# 1570    Reese Olson  4.319998  0.2507  1.189090    0.044119   0.017490
# 1828  Andrew Heaney  4.082917  0.2322  1.368289    0.041986   0.021455
# 1893  Nestor Cortes  4.973687  0.2519  1.247369    0.048180   0.014208
# 2433      Bryan Woo  4.209124  0.2507  1.209125    0.035925   0.011314
#
#       Season Role     IP  cluster
# 741     2023   SP  103.0        3
# 1570    2023   SP   91.2        0
# 1828    2023   SP  136.2        1
# 1893    2023   SP   63.1        1
# 2433    2023   SP   87.2        0

# %%
sp_pitchers['cluster'] = model.predict(scaler.transform(sp_pitchers[['ERA', 'K_pct', 'WHIP', 'delta_diff', 'delta_avg']]))

sp_pitchers.head()
# Out:
#                Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 15     Zack Greinke  5.015267  0.1621  1.267176    0.006770   0.006281
# 60   Chase Anderson  5.754101  0.1751  1.475410    0.016090   0.006810
# 88     Jordan Lyles  6.281414  0.1604  1.243900    0.005703   0.011692
# 113     Kyle Gibson  4.734375  0.1945  1.317708    0.000526   0.002900
# 164  Taijuan Walker  4.378370  0.1883  1.308878    0.020204  -0.005593
#
#      Season Role     IP  cluster
# 15     2023   SP  131.0        1
# 60     2023   SP   81.1        1
# 88     2023   SP  177.2        1
# 113    2023   SP  192.0        1
# 164    2023   SP  172.2        1

# %%
sp_cluster_2 = sp_pitchers[sp_pitchers['cluster'] == 2]

sp_cluster_2.sort_values(by='ERA', ascending=True).head(40)
# Out:
#                   Name       ERA   K_pct      WHIP  delta_diff  delta_avg  \
# 2454       Blake Snell  2.250000  0.3154  1.188889    0.028536  -0.023045
# 2358  Brandon Woodruff  2.283582  0.2925  0.820896    0.012114  -0.017228
# 2437   Clayton Kershaw  2.460753  0.2620  1.063288    0.006123  -0.017054
# 2325       Gerrit Cole  2.626794  0.2704  0.980861    0.000144  -0.013463
# 2243       Cole Ragans  2.637208  0.3112  1.074418    0.005201  -0.010064
# 2062      Tarik Skubal  2.800831  0.3290  0.896266    0.001286  -0.016326
#
#       Season Role     IP  cluster
# 2454    2023   SP  180.0        2
# 2358    2023   SP   67.0        2
# 2437    2023   SP  131.2        2
# 2325    2023   SP  209.0        2
# 2243    2023   SP   71.2        2
# 2062    2023   SP   80.1        2
